# %% [markdown]
# ## Executive Summary
#
# This project explored data from the Centers of Medicare & Medicaid Services (CMS) on nursing home provider information in order to fit a feed-forward deep neural network machine learning model to predict the binary outcome of whether any given nursing will be cited for abuse. We discovered that by feeding the continuous and boolean features of the average number of residents per day, whether a provider resides in a hospital, whether their most recent health inspection was more than two years ago, whether a provider changed ownership within the last 12 months, the total number of penalties that a nursing home has received from CMS, and the reported nurse aide, LPN, RN, total licensed staffing, and total nurse staffing hours per resident per day, can predict whether a nursing home will be cited for abuse about 66% of the time.

# %% [markdown]
# ## Introduction
#
# Staffing levels in nursing homes have long been known to be correlative or outright predictive of a variety of outcomes, such as whether residents are victims of abuse (Dicken, 2019), overall low quality of care (Dummit, 2002; Harrington et al., 2016), and even injury to nursing home staff themselves (Trinkoff et al., 2005). These effects are known to exist on political (Blankart et al., 2019), financial (Grabowski et al., 2017), and geographic (Park & Martin, 2018) lines. Adequately addressing the staffing needs of nursing homes in the United States is a major problem with no easy solutions, given the difficulties of working in such settings and the needs of the particular patients who reside within them.
#
# The purpose of this study was to explore the extent to which the average number of residents per day, whether a provider resides in a hospital, whether their most recent health inspection was more than two years ago, whether a provider changed ownership within the last 12 months, the total number of penalties that a nursing home has received from CMS, and the reported nurse aide, LPN, RN, total licensed staffing, and total nurse staffing hours per resident per day can predict whether a nursing home will be cited for abuse. Addressing staffing needs in nursing homes must begin long before a staff person walks through any particular set of nursing home doors (Jane Banaszak-Holl et al., 2002) and has implications for how nursing home staff are compensated, suggesting changes needed at the federal level for reimbursement rates for nursing home medical professionals (Konetzka et al., 2006). However, other dimensions, such as ownership, setting, and health inspection status, may also be important.
#
# We apply a TensorFlow feed-forward deep neural network model to this predictive exercise.

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import tensorflow as tf

# %%
df = pd.read_csv('Provider_Info.csv').set_index('Federal Provider Number')

# %% [markdown]
# ## Preparation
#
# We'll take a look at our data and figure out what we need to do to prepare it for a TensorFlow DNN.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15491 entries, 45198 to 675792
# Data columns (total 85 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Provider Name                                                    15491 non-null  object
#  1   Provider Address                                                 15491 non-null  object
#  2   Provider City                                                    15491 non-null  object
#  3   Provider State                                                   15491 non-null  object
#  4   Provider Zip Code                                                15491 non-null  int64
#  5   Provider Phone Number                                            15491 non-null  int64
#  6   Provider SSA County Code                                         15491 non-null  int64
#  7   Provider County Name                                             15491 non-null  object
#  8   Ownership Type                                                   15491 non-null  object
#  9   Number of Certified Beds                                         15491 non-null  int64
#  10  Average Number of Residents Per Day                              15428 non-null  float64
#  11  Provider Type                                                    15491 non-null  object
#  12  Provider Resides in Hospital                                     15491 non-null  bool
#  13  Legal Business Name                                              15491 non-null  object
#  14  Date First Approved to Provide Medicare and Medicaid services    15491 non-null  object
#  15  Continuing Care Retirement Community                             15491 non-null  bool
#  16  Special Focus Status                                             527 non-null    object
#  17  Cited for Abuse                                                  15491 non-null  bool
#  18  Most Recent Health Inspection More Than 2 Years Ago              15491 non-null  bool
#  19  Provider Changed Ownership in Last 12 Months                     15491 non-null  bool
#  20  With a Resident and Family Council                               15491 non-null  object
#  21  Automatic Sprinkler Systems in All Required Areas                15491 non-null  object
#  22  Overall Rating                                                   15313 non-null  float64
#  23  Overall Rating Footnote                                          178 non-null    float64
#  24  Health Inspection Rating                                         15313 non-null  float64
#  25  Health Inspection Rating Footnote                                178 non-null    float64
#  26  QM Rating                                                        15291 non-null  float64
#  27  QM Rating Footnote                                               200 non-null    float64
#  28  Long-Stay QM Rating                                              14860 non-null  float64
#  29  Long-Stay QM Rating Footnote                                     631 non-null    float64
#  30  Short-Stay QM Rating                                             13677 non-null  float64
#  31  Short-Stay QM Rating Footnote                                    1814 non-null   float64
#  32  Staffing Rating                                                  15238 non-null  float64
#  33  Staffing Rating Footnote                                         1447 non-null   float64
#  34  RN Staffing Rating                                               15238 non-null  float64
#  35  RN Staffing Rating Footnote                                      1447 non-null   float64
#  36  Reported Staffing Footnote                                       576 non-null    float64
#  37  Physical Therapist Staffing Footnote                             576 non-null    float64
#  38  Reported Nurse Aide Staffing Hours per Resident per Day          14915 non-null  float64
#  39  Reported LPN Staffing Hours per Resident per Day                 14915 non-null  float64
#  40  Reported RN Staffing Hours per Resident per Day                  14915 non-null  float64
#  41  Reported Licensed Staffing Hours per Resident per Day            14915 non-null  float64
#  42  Reported Total Nurse Staffing Hours per Resident per Day         14915 non-null  float64
#  43  Reported Physical Therapist Staffing Hours per Resident Per Day  14915 non-null  float64
#  44  Case-Mix Nurse Aide Staffing Hours per Resident per Day          14915 non-null  float64
#  45  Case-Mix LPN Staffing Hours per Resident per Day                 14915 non-null  float64
#  46  Case-Mix RN Staffing Hours per Resident per Day                  14915 non-null  float64
#  47  Case-Mix Total Nurse Staffing Hours per Resident per Day         14915 non-null  float64
#  48  Adjusted Nurse Aide Staffing Hours per Resident per Day          14860 non-null  float64
#  49  Adjusted LPN Staffing Hours per Resident per Day                 14860 non-null  float64
#  50  Adjusted RN Staffing Hours per Resident per Day                  14860 non-null  float64
#  51  Adjusted Total Nurse Staffing Hours per Resident per Day         14860 non-null  float64
#  52  Rating Cycle 1 Standard Survey Health Date                       15491 non-null  object
#  53  Rating Cycle 1 Total Number of Health Deficiencies               15400 non-null  float64
#  54  Rating Cycle 1 Number of Standard Health Deficiencies            15400 non-null  float64
#  55  Rating Cycle 1 Number of Complaint Health Deficiencies           15400 non-null  float64
#  56  Rating Cycle 1 Health Deficiency Score                           15400 non-null  float64
#  57  Rating Cycle 1 Number of Health Revisits                         15400 non-null  float64
#  58  Rating Cycle 1 Health Revisit Score                              15400 non-null  float64
#  59  Rating Cycle 1 Total Health Score                                15400 non-null  float64
#  60  Rating Cycle 2 Standard Health Survey Date                       15400 non-null  object
#  61  Rating Cycle 2 Total Number of Health Deficiencies               15491 non-null  object
#  62  Rating Cycle 2 Number of Standard Health Deficiencies            15491 non-null  object
#  63  Rating Cycle 2 Number of Complaint Health Deficiencies           15400 non-null  float64
#  64  Rating Cycle 2 Health Deficiency Score                           15400 non-null  float64
#  65  Rating Cycle 2 Number of Health Revisits                         15400 non-null  float64
#  66  Rating Cycle 2 Health Revisit Score                              15400 non-null  float64
#  67  Rating Cycle 2 Total Health Score                                15400 non-null  float64
#  68  Rating Cycle 3 Standard Health Survey Date                       15272 non-null  object
#  69  Rating Cycle 3 Total Number of Health Deficiencies               15491 non-null  object
#  70  Rating Cycle 3 Number of Standard Health Deficiencies            15491 non-null  object
#  71  Rating Cycle 3 Number of Complaint Health Deficiencies           15491 non-null  object
#  72  Rating Cycle 3 Number of Health Revisits                         15491 non-null  object
#  73  Rating Cycle 3 Health Deficiency Score                           15491 non-null  object
#  74  Rating Cycle 3 Health Revisit Score                              15491 non-null  object
#  75  Rating Cycle 3 Total Health Score                                15491 non-null  object
#  76  Total Weighted Health Survey Score                               15400 non-null  float64
#  77  Number of Facility Reported Incidents                            15491 non-null  int64
#  78  Number of Substantiated Complaints                               15491 non-null  int64
#  79  Number of Fines                                                  15491 non-null  int64
#  80  Total Amount of Fines in Dollars                                 15491 non-null  float64
#  81  Number of Payment Denials                                        15491 non-null  int64
#  82  Total Number of Penalties                                        15491 non-null  int64
#  83  Location                                                         15468 non-null  object
#  84  Processing Date                                                  15491 non-null  object
# dtypes: bool(5), float64(45), int64(9), object(26)
# memory usage: 9.6+ MB

# %% [markdown]
# For our purposes here, we're only interested in continuous and Boolean features, so we'll filter those out.

# %%
df = df.select_dtypes(include=['int64', 'float64', 'bool'])
df.columns.to_list()
# Out:
# ['Provider Zip Code',
#  'Provider Phone Number',
#  'Provider SSA County Code',
#  'Number of Certified Beds',
#  'Average Number of Residents Per Day',
#  'Provider Resides in Hospital',
#  'Continuing Care Retirement Community',
#  'Cited for Abuse',
#  'Most Recent Health Inspection More Than 2 Years Ago',
#  'Provider Changed Ownership in Last 12 Months',
#  'Overall Rating',
#  'Overall Rating Footnote',
#  'Health Inspection Rating',
#  'Health Inspection Rating Footnote',
#  'QM Rating',
#  'QM Rating Footnote',
#  'Long-Stay QM Rating',
#  'Long-Stay QM Rating Footnote',
#  'Short-Stay QM Rating',
#  'Short-Stay QM Rating Footnote',
#  'Staffing Rating',
#  'Staffing Rating Footnote',
#  'RN Staffing Rating',
#  'RN Staffing Rating Footnote',
#  'Reported Staffing Footnote',
#  'Physical Therapist Staffing Footnote',
#  'Reported Nurse Aide Staffing Hours per Resident per Day',
#  'Reported LPN Staffing Hours per Resident per Day',
#  'Reported RN Staffing Hours per Resident per Day',
#  'Reported Licensed Staffing Hours per Resident per Day',
#  'Reported Total Nurse Staffing Hours per Resident per Day',
#  'Reported Physical Therapist Staffing Hours per Resident Per Day',
#  'Case-Mix Nurse Aide Staffing Hours per Resident per Day',
#  'Case-Mix LPN Staffing Hours per Resident per Day',
#  'Case-Mix RN Staffing Hours per Resident per Day',
#  'Case-Mix Total Nurse Staffing Hours per Resident per Day',
#  'Adjusted Nurse Aide Staffing Hours per Resident per Day',
#  'Adjusted LPN Staffing Hours per Resident per Day',
#  'Adjusted RN Staffing Hours per Resident per Day',
#  'Adjusted Total Nurse Staffing Hours per Resident per Day',
#  'Rating Cycle 1 Total Number of Health Deficiencies',
#  'Rating Cycle 1 Number of Standard Health Deficiencies',
#  'Rating Cycle 1 Number of Complaint Health Deficiencies',
#  'Rating Cycle 1 Health Deficiency Score',
#  'Rating Cycle 1 Number of Health Revisits',
#  'Rating Cycle 1 Health Revisit Score',
#  'Rating Cycle 1 Total Health Score',
#  'Rating Cycle 2 Number of Complaint Health Deficiencies',
#  'Rating Cycle 2 Health Deficiency Score',
#  'Rating Cycle 2 Number of Health Revisits',
#  'Rating Cycle 2 Health Revisit Score',
#  'Rating Cycle 2 Total Health Score',
#  'Total Weighted Health Survey Score',
#  'Number of Facility Reported Incidents',
#  'Number of Substantiated Complaints',
#  'Number of Fines',
#  'Total Amount of Fines in Dollars',
#  'Number of Payment Denials',
#  'Total Number of Penalties']

# %%
cols = [
 'Average Number of Residents Per Day',
 'Provider Resides in Hospital',
 'Most Recent Health Inspection More Than 2 Years Ago',
 'Provider Changed Ownership in Last 12 Months',
 'Total Number of Penalties',
 'Reported Nurse Aide Staffing Hours per Resident per Day',
 'Reported LPN Staffing Hours per Resident per Day',
 'Reported RN Staffing Hours per Resident per Day',
 'Reported Licensed Staffing Hours per Resident per Day',
 'Reported Total Nurse Staffing Hours per Resident per Day',
 'Cited for Abuse'
]

# %% [markdown]
# We don't want NaNs in our dataset so we'll filter those out.

# %%
snf_data = df[cols].dropna()
snf_data
# Out:
#                          Average Number of Residents Per Day  \
# Federal Provider Number
# 55249                                                   78.2
# 55305                                                   50.4
# 55341                                                   63.2
# 55612                                                   38.8
# 55653                                                  237.8
# ...                                                      ...
# 445472                                                  43.9
# 515185                                                  74.8
# 365081                                                  92.8
# 395715                                                 112.6
# 675792                                                  63.6
#
#                          Provider Resides in Hospital  \
# Federal Provider Number
# 55249                                           False
# 55305                                           False
# 55341                                           False
# 55612                                           False
# 55653                                           False
# ...                                               ...
# 445472                                          False
# 515185                                          False
# 365081                                          False
# 395715                                          False
# 675792                                          False
#
#                          Most Recent Health Inspection More Than 2 Years Ago  \
# Federal Provider Number
# 55249                                                                False
# 55305                                                                False
# 55341                                                                False
# 55612                                                                False
# 55653                                                                False
# ...                                                                    ...
# 445472                                                               False
# 515185                                                               False
# 365081                                                               False
# 395715                                                               False
# 675792                                                               False
#
#                          Provider Changed Ownership in Last 12 Months  \
# Federal Provider Number
# 55249                                                           False
# 55305                                                           False
# 55341                                                           False
# 55612                                                           False
# 55653                                                           False
# ...                                                               ...
# 445472                                                          False
# 515185                                                          False
# 365081                                                          False
# 395715                                                          False
# 675792                                                          False
#
#                          Total Number of Penalties  \
# Federal Provider Number
# 55249                                            0
# 55305                                            0
# 55341                                            0
# 55612                                            2
# 55653                                            0
# ...                                            ...
# 445472                                           0
# 515185                                           1
# 365081                                           1
# 395715                                           0
# 675792                                           0
#
#                          Reported Nurse Aide Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                              2.38684
# 55305                                                              2.58358
# 55341                                                              2.54925
# 55612                                                              2.58972
# 55653                                                              1.85290
# ...                                                                    ...
# 445472                                                             3.38602
# 515185                                                             1.91819
# 365081                                                             1.78861
# 395715                                                             2.16631
# 675792                                                             1.73098
#
#                          Reported LPN Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                             1.06150
# 55305                                                             0.82247
# 55341                                                             1.24482
# 55612                                                             1.11114
# 55653                                                             1.17694
# ...                                                                   ...
# 445472                                                            1.52456
# 515185                                                            1.16817
# 365081                                                            0.94269
# 395715                                                            0.97703
# 675792                                                            1.24356
#
#                          Reported RN Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                            0.22008
# 55305                                                            0.30496
# 55341                                                            0.71746
# 55612                                                            0.40391
# 55653                                                            0.54549
# ...                                                                  ...
# 445472                                                           0.92610
# 515185                                                           0.48395
# 365081                                                           0.72234
# 395715                                                           0.60666
# 675792                                                           0.26513
#
#                          Reported Licensed Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                              1.28158
# 55305                                                              1.12743
# 55341                                                              1.96228
# 55612                                                              1.51505
# 55653                                                              1.72243
# ...                                                                    ...
# 445472                                                             2.45066
# 515185                                                             1.65212
# 365081                                                             1.66503
# 395715                                                             1.58369
# 675792                                                             1.50869
#
#                          Reported Total Nurse Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                              3.66843
# 55305                                                              3.71100
# 55341                                                              4.51153
# 55612                                                              4.10477
# 55653                                                              3.57533
# ...                                                                    ...
# 445472                                                             5.83668
# 515185                                                             3.57030
# 365081                                                             3.45365
# 395715                                                             3.75000
# 675792                                                             3.23967
#
#                          Cited for Abuse
# Federal Provider Number
# 55249                              False
# 55305                              False
# 55341                              False
# 55612                               True
# 55653                              False
# ...                                  ...
# 445472                             False
# 515185                             False
# 365081                             False
# 395715                             False
# 675792                             False
#
# [14915 rows x 11 columns]

# %% [markdown]
# We'll be passing our dataframe into a separate .csv file after it's prepared, and then using Numpy's loadtxt() function to produce an array of raw data to prepare for our DNN model. Because of this, we want to deal with the Boolean values here and make sure they get stored as numerical representations instead of text, i.e. we want 1s and 0s. We'll explicitly convert them all to integers, then load our data into a separate .csv file:

# %%
bool_cols = snf_data.select_dtypes(include=['bool']).columns.to_list()
snf_data[bool_cols] *= 1

# %%
snf_data
# Out:
#                          Average Number of Residents Per Day  \
# Federal Provider Number
# 55249                                                   78.2
# 55305                                                   50.4
# 55341                                                   63.2
# 55612                                                   38.8
# 55653                                                  237.8
# ...                                                      ...
# 445472                                                  43.9
# 515185                                                  74.8
# 365081                                                  92.8
# 395715                                                 112.6
# 675792                                                  63.6
#
#                          Provider Resides in Hospital  \
# Federal Provider Number
# 55249                                               0
# 55305                                               0
# 55341                                               0
# 55612                                               0
# 55653                                               0
# ...                                               ...
# 445472                                              0
# 515185                                              0
# 365081                                              0
# 395715                                              0
# 675792                                              0
#
#                          Most Recent Health Inspection More Than 2 Years Ago  \
# Federal Provider Number
# 55249                                                                    0
# 55305                                                                    0
# 55341                                                                    0
# 55612                                                                    0
# 55653                                                                    0
# ...                                                                    ...
# 445472                                                                   0
# 515185                                                                   0
# 365081                                                                   0
# 395715                                                                   0
# 675792                                                                   0
#
#                          Provider Changed Ownership in Last 12 Months  \
# Federal Provider Number
# 55249                                                               0
# 55305                                                               0
# 55341                                                               0
# 55612                                                               0
# 55653                                                               0
# ...                                                               ...
# 445472                                                              0
# 515185                                                              0
# 365081                                                              0
# 395715                                                              0
# 675792                                                              0
#
#                          Total Number of Penalties  \
# Federal Provider Number
# 55249                                            0
# 55305                                            0
# 55341                                            0
# 55612                                            2
# 55653                                            0
# ...                                            ...
# 445472                                           0
# 515185                                           1
# 365081                                           1
# 395715                                           0
# 675792                                           0
#
#                          Reported Nurse Aide Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                              2.38684
# 55305                                                              2.58358
# 55341                                                              2.54925
# 55612                                                              2.58972
# 55653                                                              1.85290
# ...                                                                    ...
# 445472                                                             3.38602
# 515185                                                             1.91819
# 365081                                                             1.78861
# 395715                                                             2.16631
# 675792                                                             1.73098
#
#                          Reported LPN Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                             1.06150
# 55305                                                             0.82247
# 55341                                                             1.24482
# 55612                                                             1.11114
# 55653                                                             1.17694
# ...                                                                   ...
# 445472                                                            1.52456
# 515185                                                            1.16817
# 365081                                                            0.94269
# 395715                                                            0.97703
# 675792                                                            1.24356
#
#                          Reported RN Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                            0.22008
# 55305                                                            0.30496
# 55341                                                            0.71746
# 55612                                                            0.40391
# 55653                                                            0.54549
# ...                                                                  ...
# 445472                                                           0.92610
# 515185                                                           0.48395
# 365081                                                           0.72234
# 395715                                                           0.60666
# 675792                                                           0.26513
#
#                          Reported Licensed Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                              1.28158
# 55305                                                              1.12743
# 55341                                                              1.96228
# 55612                                                              1.51505
# 55653                                                              1.72243
# ...                                                                    ...
# 445472                                                             2.45066
# 515185                                                             1.65212
# 365081                                                             1.66503
# 395715                                                             1.58369
# 675792                                                             1.50869
#
#                          Reported Total Nurse Staffing Hours per Resident per Day  \
# Federal Provider Number
# 55249                                                              3.66843
# 55305                                                              3.71100
# 55341                                                              4.51153
# 55612                                                              4.10477
# 55653                                                              3.57533
# ...                                                                    ...
# 445472                                                             5.83668
# 515185                                                             3.57030
# 365081                                                             3.45365
# 395715                                                             3.75000
# 675792                                                             3.23967
#
#                          Cited for Abuse
# Federal Provider Number
# 55249                                  0
# 55305                                  0
# 55341                                  0
# 55612                                  1
# 55653                                  0
# ...                                  ...
# 445472                                 0
# 515185                                 0
# 365081                                 0
# 395715                                 0
# 675792                                 0
#
# [14915 rows x 11 columns]

# %%
snf_data.to_csv('NursingHome_data.csv', index=False, header=None)

# %% [markdown]
# ## Preparing a feed-forward deep neural network model
#
# ### Extracting the data
#
# Here, we take our prepared .csv file from the previous steps and load it into two Numpy arrays, one for our features and one for our target, which is the Boolean value for whether a nursing home has been cited for abuse:

# %%
snf_data_np = np.loadtxt('NursingHome_data.csv', delimiter=',')

unscaled_inputs_all = snf_data_np[:,1:-1]
targets_all = snf_data_np[:,-1]

# %%
unscaled_inputs_all
# Out:
# array([[0.     , 0.     , 0.     , ..., 0.22008, 1.28158, 3.66843],
#        [0.     , 0.     , 0.     , ..., 0.30496, 1.12743, 3.711  ],
#        [0.     , 0.     , 0.     , ..., 0.71746, 1.96228, 4.51153],
#        ...,
#        [0.     , 0.     , 0.     , ..., 0.72234, 1.66503, 3.45365],
#        [0.     , 0.     , 0.     , ..., 0.60666, 1.58369, 3.75   ],
#        [0.     , 0.     , 0.     , ..., 0.26513, 1.50869, 3.23967]])

# %%
targets_all
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# ### Balancing the data
#
# When be balance the data for a binary predictive outcome, we're making sure that we have an equal number of 0s and 1s so that our model works on  data it's never seen before. We do this by first getting the sum of the 1s in the target feature, setting a counter to zero, and then setting an empty list to store the indices that we'll take out of our dataset to get this 1:1 ratio:

# %%
# balancing the dataset

num_one_targets = int(np.sum(targets_all))
zero_targets_counter = 0
indices_to_remove = []

for i in range(targets_all.shape[0]):
    if targets_all[i] == 0:
        zero_targets_counter += 1
        if zero_targets_counter > num_one_targets:
            indices_to_remove.append(i)
            
unscaled_inputs_equal_priors = np.delete(unscaled_inputs_all, indices_to_remove, axis=0)
targets_equal_priors = np.delete(targets_all, indices_to_remove, axis=0)

# %% [markdown]
# ### Scaling the data
#
# Next, we need to make sure that our data is intelligible between features. We do this by scaling all our values on a common scale so that they relate to each other by equal weight. We use scikit's preprossing scale() function to do this:

# %%
scaled_inputs = preprocessing.scale(unscaled_inputs_equal_priors)

# %% [markdown]
# ### Shuffilng the data
#
# It's generally a good idea to shuffle things around so that the model has a "more random" dataset.

# %%
shuffled_indices = np.arange(scaled_inputs.shape[0])
np.random.shuffle(shuffled_indices)

shuffled_inputs = scaled_inputs[shuffled_indices]
shuffled_targets = targets_equal_priors[shuffled_indices]

# %% [markdown]
# ### Splitting the dataset into train, validation, and test sets
#
# Here, we create three separate datasets for our model. We will use the training set to set a baseline for our model to learn, the validation set to measure the training results on a temporary basis, and the test set to validate our model on a permanent basis. This three-way split is important because once we deploy the model on the test set, we can no longer change any parameters or hyperparameters  because it would then be a different model; that's why we need the validation set. We create and validate the splits like so:

# %%
# splitting into train, validation, and test
samples_count = shuffled_inputs.shape[0]

train_samples_count = int(0.8*samples_count)
validation_samples_count = int(0.1*samples_count)
test_samples_count = samples_count - train_samples_count - validation_samples_count

train_inputs = shuffled_inputs[:train_samples_count]
train_targets = shuffled_targets[:train_samples_count]

validation_inputs = shuffled_inputs[train_samples_count:train_samples_count+validation_samples_count]
validation_targets = shuffled_targets[train_samples_count:train_samples_count+validation_samples_count]

test_inputs = shuffled_inputs[train_samples_count+validation_samples_count:]
test_targets = shuffled_targets[train_samples_count+validation_samples_count:]

# %%
print(np.sum(train_targets), train_samples_count, np.sum(train_targets) / train_samples_count)
print(np.sum(validation_targets), validation_samples_count, np.sum(validation_targets) / validation_samples_count)
print(np.sum(test_targets), test_samples_count, np.sum(test_targets) / test_samples_count)
# Out:
# 588.0 1171 0.502134927412468
# 75.0 146 0.5136986301369864
# 69.0 147 0.46938775510204084

# %% [markdown]
# ### Saving the data into *.npz files
#
# TensorFlow needs data in tensor format to make sense if it. It turns out that .npz files are tensor-friendly, se we'll create those files from our three-way split data:

# %%
# saving in tensorflow-friendly format
np.savez('SNF_data_train', inputs=train_inputs, targets=train_targets)
np.savez('SNF_data_validation', inputs=validation_inputs, targets=validation_targets)
np.savez('SNF_data_test', inputs=test_inputs, targets=test_targets)

# %% [markdown]
# ### Loading the data back in
#
# Here, we read the .npz files and create the train, validation, and test datasets from them:

# %%
npz = np.load('SNF_data_train.npz')

train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('SNF_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

npz = np.load('SNF_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %% [markdown]
# ### Creating the model
#
# Now we finally create our feed-forward DNN. Our input size is the number of features we introduce for the model to learn from; in this case, we have 10 features minus the target. The output size is either a 0 or a 1 for "Cited for Abuse," so the value is 2. The hidden layer size is the number of permutations that the machine goes through to arrive at a prediction of 0 or 1; this can be arbitrary, but in this case we'll go with 50, which is a lot, but this can vary regardless. Next, we create the hidden layers and specify their activation function; in this case, we're choosing the ReLU function, which stands for "rectified linear unit." We understand it to be commonly used and the mathematics behind it are outside the scope of this particular project (though this obviously is important). Finally we compile our model, choosing our optimizer function, here Adam, use sparse categorical cross-entropy for our loss funchion, set our caluclation batch to 100 and instruct the machine to run through 100 epochs, or total cycles to arrive at our final calculations:

# %%
input_size = 10                 # number of predictors
output_size = 2                 # only two outputs
hidden_layer_size = 50         # kind of arbitrary? Not sure how to choose this

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size = 100

max_epochs = 100

model.fit(train_inputs, train_targets, batch_size=batch_size, epochs=max_epochs, validation_data=(validation_inputs, validation_targets), verbose=2)
# Out:
# Train on 1171 samples, validate on 146 samples
# Epoch 1/100
# 1171/1171 - 1s - loss: 0.6997 - accuracy: 0.5337 - val_loss: 0.6723 - val_accuracy: 0.6096
# Epoch 2/100
# 1171/1171 - 0s - loss: 0.6503 - accuracy: 0.6593 - val_loss: 0.6431 - val_accuracy: 0.6370
# Epoch 3/100
# 1171/1171 - 0s - loss: 0.6221 - accuracy: 0.6781 - val_loss: 0.6334 - val_accuracy: 0.6712
# Epoch 4/100
# 1171/1171 - 0s - loss: 0.6050 - accuracy: 0.6994 - val_loss: 0.6253 - val_accuracy: 0.6918
# Epoch 5/100
# 1171/1171 - 0s - loss: 0.5969 - accuracy: 0.6985 - val_loss: 0.6252 - val_accuracy: 0.6918
# Epoch 6/100
# 1171/1171 - 0s - loss: 0.5935 - accuracy: 0.6960 - val_loss: 0.6235 - val_accuracy: 0.6849
# Epoch 7/100
# 1171/1171 - 0s - loss: 0.5900 - accuracy: 0.7020 - val_loss: 0.6226 - val_accuracy: 0.6849
# Epoch 8/100
# 1171/1171 - 0s - loss: 0.5884 - accuracy: 0.7071 - val_loss: 0.6235 - val_accuracy: 0.6849
# Epoch 9/100
# 1171/1171 - 0s - loss: 0.5896 - accuracy: 0.7020 - val_loss: 0.6307 - val_accuracy: 0.6849
# Epoch 10/100
# 1171/1171 - 0s - loss: 0.5860 - accuracy: 0.7131 - val_loss: 0.6216 - val_accuracy: 0.6918
# Epoch 11/100
# 1171/1171 - 0s - loss: 0.5845 - accuracy: 0.7054 - val_loss: 0.6264 - val_accuracy: 0.6849
# Epoch 12/100
# 1171/1171 - 0s - loss: 0.5839 - accuracy: 0.7054 - val_loss: 0.6257 - val_accuracy: 0.6918
# Epoch 13/100
# 1171/1171 - 0s - loss: 0.5825 - accuracy: 0.7037 - val_loss: 0.6245 - val_accuracy: 0.6918
# Epoch 14/100
# 1171/1171 - 0s - loss: 0.5816 - accuracy: 0.7054 - val_loss: 0.6235 - val_accuracy: 0.6918
# Epoch 15/100
# 1171/1171 - 0s - loss: 0.5809 - accuracy: 0.7062 - val_loss: 0.6258 - val_accuracy: 0.6918
# Epoch 16/100
# 1171/1171 - 0s - loss: 0.5800 - accuracy: 0.7045 - val_loss: 0.6243 - val_accuracy: 0.6986
# Epoch 17/100
# 1171/1171 - 0s - loss: 0.5792 - accuracy: 0.7054 - val_loss: 0.6268 - val_accuracy: 0.6918
# Epoch 18/100
# 1171/1171 - 0s - loss: 0.5790 - accuracy: 0.7045 - val_loss: 0.6240 - val_accuracy: 0.6849
# Epoch 19/100
# 1171/1171 - 0s - loss: 0.5774 - accuracy: 0.7054 - val_loss: 0.6221 - val_accuracy: 0.6849
# Epoch 20/100
# 1171/1171 - 0s - loss: 0.5778 - accuracy: 0.7045 - val_loss: 0.6222 - val_accuracy: 0.6986
# Epoch 21/100
# 1171/1171 - 0s - loss: 0.5776 - accuracy: 0.6977 - val_loss: 0.6239 - val_accuracy: 0.6918
# Epoch 22/100
# 1171/1171 - 0s - loss: 0.5765 - accuracy: 0.7079 - val_loss: 0.6289 - val_accuracy: 0.6849
# Epoch 23/100
# 1171/1171 - 0s - loss: 0.5783 - accuracy: 0.7062 - val_loss: 0.6210 - val_accuracy: 0.6781
# Epoch 24/100
# 1171/1171 - 0s - loss: 0.5734 - accuracy: 0.7079 - val_loss: 0.6289 - val_accuracy: 0.6849
# Epoch 25/100
# 1171/1171 - 0s - loss: 0.5757 - accuracy: 0.7088 - val_loss: 0.6241 - val_accuracy: 0.6918
# Epoch 26/100
# 1171/1171 - 0s - loss: 0.5748 - accuracy: 0.7020 - val_loss: 0.6213 - val_accuracy: 0.6781
# Epoch 27/100
# 1171/1171 - 0s - loss: 0.5742 - accuracy: 0.7028 - val_loss: 0.6282 - val_accuracy: 0.6849
# Epoch 28/100
# 1171/1171 - 0s - loss: 0.5725 - accuracy: 0.7062 - val_loss: 0.6230 - val_accuracy: 0.6781
# Epoch 29/100
# 1171/1171 - 0s - loss: 0.5729 - accuracy: 0.7003 - val_loss: 0.6230 - val_accuracy: 0.6781
# Epoch 30/100
# 1171/1171 - 0s - loss: 0.5713 - accuracy: 0.7037 - val_loss: 0.6286 - val_accuracy: 0.6849
# Epoch 31/100
# 1171/1171 - 0s - loss: 0.5710 - accuracy: 0.7079 - val_loss: 0.6255 - val_accuracy: 0.6849
# Epoch 32/100
# 1171/1171 - 0s - loss: 0.5712 - accuracy: 0.7020 - val_loss: 0.6238 - val_accuracy: 0.6849
# Epoch 33/100
# 1171/1171 - 0s - loss: 0.5698 - accuracy: 0.7037 - val_loss: 0.6235 - val_accuracy: 0.6849
# Epoch 34/100
# 1171/1171 - 0s - loss: 0.5694 - accuracy: 0.7062 - val_loss: 0.6271 - val_accuracy: 0.6918
# Epoch 35/100
# 1171/1171 - 0s - loss: 0.5696 - accuracy: 0.7088 - val_loss: 0.6267 - val_accuracy: 0.6849
# Epoch 36/100
# 1171/1171 - 0s - loss: 0.5687 - accuracy: 0.7062 - val_loss: 0.6266 - val_accuracy: 0.6781
# Epoch 37/100
# 1171/1171 - 0s - loss: 0.5692 - accuracy: 0.7003 - val_loss: 0.6256 - val_accuracy: 0.6712
# Epoch 38/100
# 1171/1171 - 0s - loss: 0.5669 - accuracy: 0.7088 - val_loss: 0.6231 - val_accuracy: 0.6712
# Epoch 39/100
# 1171/1171 - 0s - loss: 0.5665 - accuracy: 0.7071 - val_loss: 0.6280 - val_accuracy: 0.6781
# Epoch 40/100
# 1171/1171 - 0s - loss: 0.5694 - accuracy: 0.7079 - val_loss: 0.6249 - val_accuracy: 0.6849
# Epoch 41/100
# 1171/1171 - 0s - loss: 0.5667 - accuracy: 0.7079 - val_loss: 0.6297 - val_accuracy: 0.6781
# Epoch 42/100
# 1171/1171 - 0s - loss: 0.5648 - accuracy: 0.7139 - val_loss: 0.6254 - val_accuracy: 0.6712
# Epoch 43/100
# 1171/1171 - 0s - loss: 0.5652 - accuracy: 0.7096 - val_loss: 0.6293 - val_accuracy: 0.6918
# Epoch 44/100
# 1171/1171 - 0s - loss: 0.5651 - accuracy: 0.7079 - val_loss: 0.6273 - val_accuracy: 0.6986
# Epoch 45/100
# 1171/1171 - 0s - loss: 0.5649 - accuracy: 0.7079 - val_loss: 0.6270 - val_accuracy: 0.6712
# Epoch 46/100
# 1171/1171 - 0s - loss: 0.5644 - accuracy: 0.7156 - val_loss: 0.6268 - val_accuracy: 0.6849
# Epoch 47/100
# 1171/1171 - 0s - loss: 0.5632 - accuracy: 0.7114 - val_loss: 0.6285 - val_accuracy: 0.6781
# Epoch 48/100
# 1171/1171 - 0s - loss: 0.5642 - accuracy: 0.7079 - val_loss: 0.6264 - val_accuracy: 0.6781
# Epoch 49/100
# 1171/1171 - 0s - loss: 0.5623 - accuracy: 0.7105 - val_loss: 0.6296 - val_accuracy: 0.6781
# Epoch 50/100
# 1171/1171 - 0s - loss: 0.5617 - accuracy: 0.7088 - val_loss: 0.6283 - val_accuracy: 0.6849
# Epoch 51/100
# 1171/1171 - 0s - loss: 0.5604 - accuracy: 0.7139 - val_loss: 0.6298 - val_accuracy: 0.6781
# Epoch 52/100
# 1171/1171 - 0s - loss: 0.5614 - accuracy: 0.7165 - val_loss: 0.6248 - val_accuracy: 0.6849
# Epoch 53/100
# 1171/1171 - 0s - loss: 0.5595 - accuracy: 0.7079 - val_loss: 0.6286 - val_accuracy: 0.6918
# Epoch 54/100
# 1171/1171 - 0s - loss: 0.5597 - accuracy: 0.7156 - val_loss: 0.6287 - val_accuracy: 0.6781
# Epoch 55/100
# 1171/1171 - 0s - loss: 0.5586 - accuracy: 0.7148 - val_loss: 0.6303 - val_accuracy: 0.6712
# Epoch 56/100
# 1171/1171 - 0s - loss: 0.5578 - accuracy: 0.7088 - val_loss: 0.6265 - val_accuracy: 0.6781
# Epoch 57/100
# 1171/1171 - 0s - loss: 0.5569 - accuracy: 0.7165 - val_loss: 0.6300 - val_accuracy: 0.6849
# Epoch 58/100
# 1171/1171 - 0s - loss: 0.5567 - accuracy: 0.7105 - val_loss: 0.6302 - val_accuracy: 0.6781
# Epoch 59/100
# 1171/1171 - 0s - loss: 0.5552 - accuracy: 0.7139 - val_loss: 0.6302 - val_accuracy: 0.6781
# Epoch 60/100
# 1171/1171 - 0s - loss: 0.5557 - accuracy: 0.7139 - val_loss: 0.6266 - val_accuracy: 0.6781
# Epoch 61/100
# 1171/1171 - 0s - loss: 0.5561 - accuracy: 0.7122 - val_loss: 0.6294 - val_accuracy: 0.6849
# Epoch 62/100
# 1171/1171 - 0s - loss: 0.5548 - accuracy: 0.7131 - val_loss: 0.6306 - val_accuracy: 0.6781
# Epoch 63/100
# 1171/1171 - 0s - loss: 0.5537 - accuracy: 0.7148 - val_loss: 0.6292 - val_accuracy: 0.6849
# Epoch 64/100
# 1171/1171 - 0s - loss: 0.5524 - accuracy: 0.7182 - val_loss: 0.6284 - val_accuracy: 0.6781
# Epoch 65/100
# 1171/1171 - 0s - loss: 0.5524 - accuracy: 0.7182 - val_loss: 0.6310 - val_accuracy: 0.6781
# Epoch 66/100
# 1171/1171 - 0s - loss: 0.5517 - accuracy: 0.7165 - val_loss: 0.6287 - val_accuracy: 0.6849
# Epoch 67/100
# 1171/1171 - 0s - loss: 0.5517 - accuracy: 0.7148 - val_loss: 0.6319 - val_accuracy: 0.6849
# Epoch 68/100
# 1171/1171 - 0s - loss: 0.5535 - accuracy: 0.7182 - val_loss: 0.6340 - val_accuracy: 0.6849
# Epoch 69/100
# 1171/1171 - 0s - loss: 0.5531 - accuracy: 0.7148 - val_loss: 0.6275 - val_accuracy: 0.6781
# Epoch 70/100
# 1171/1171 - 0s - loss: 0.5493 - accuracy: 0.7233 - val_loss: 0.6343 - val_accuracy: 0.6849
# Epoch 71/100
# 1171/1171 - 0s - loss: 0.5493 - accuracy: 0.7182 - val_loss: 0.6320 - val_accuracy: 0.6712
# Epoch 72/100
# 1171/1171 - 0s - loss: 0.5482 - accuracy: 0.7165 - val_loss: 0.6320 - val_accuracy: 0.6849
# Epoch 73/100
# 1171/1171 - 0s - loss: 0.5480 - accuracy: 0.7208 - val_loss: 0.6289 - val_accuracy: 0.6849
# Epoch 74/100
# 1171/1171 - 0s - loss: 0.5466 - accuracy: 0.7182 - val_loss: 0.6325 - val_accuracy: 0.6712
# Epoch 75/100
# 1171/1171 - 0s - loss: 0.5459 - accuracy: 0.7242 - val_loss: 0.6297 - val_accuracy: 0.6712
# Epoch 76/100
# 1171/1171 - 0s - loss: 0.5466 - accuracy: 0.7190 - val_loss: 0.6357 - val_accuracy: 0.6712
# Epoch 77/100
# 1171/1171 - 0s - loss: 0.5472 - accuracy: 0.7208 - val_loss: 0.6312 - val_accuracy: 0.6781
# Epoch 78/100
# 1171/1171 - 0s - loss: 0.5473 - accuracy: 0.7199 - val_loss: 0.6280 - val_accuracy: 0.6918
# Epoch 79/100
# 1171/1171 - 0s - loss: 0.5444 - accuracy: 0.7156 - val_loss: 0.6334 - val_accuracy: 0.6849
# Epoch 80/100
# 1171/1171 - 0s - loss: 0.5427 - accuracy: 0.7190 - val_loss: 0.6344 - val_accuracy: 0.6712
# Epoch 81/100
# 1171/1171 - 0s - loss: 0.5441 - accuracy: 0.7199 - val_loss: 0.6292 - val_accuracy: 0.6849
# Epoch 82/100
# 1171/1171 - 0s - loss: 0.5412 - accuracy: 0.7208 - val_loss: 0.6344 - val_accuracy: 0.6712
# Epoch 83/100
# 1171/1171 - 0s - loss: 0.5420 - accuracy: 0.7216 - val_loss: 0.6321 - val_accuracy: 0.6781
# Epoch 84/100
# 1171/1171 - 0s - loss: 0.5410 - accuracy: 0.7199 - val_loss: 0.6373 - val_accuracy: 0.6712
# Epoch 85/100
# 1171/1171 - 0s - loss: 0.5392 - accuracy: 0.7216 - val_loss: 0.6383 - val_accuracy: 0.6575
# Epoch 86/100
# 1171/1171 - 0s - loss: 0.5385 - accuracy: 0.7242 - val_loss: 0.6337 - val_accuracy: 0.6712
# Epoch 87/100
# 1171/1171 - 0s - loss: 0.5375 - accuracy: 0.7233 - val_loss: 0.6376 - val_accuracy: 0.6644
# Epoch 88/100
# 1171/1171 - 0s - loss: 0.5382 - accuracy: 0.7225 - val_loss: 0.6323 - val_accuracy: 0.6849
# Epoch 89/100
# 1171/1171 - 0s - loss: 0.5401 - accuracy: 0.7190 - val_loss: 0.6373 - val_accuracy: 0.6644
# Epoch 90/100
# 1171/1171 - 0s - loss: 0.5383 - accuracy: 0.7276 - val_loss: 0.6352 - val_accuracy: 0.6507
# Epoch 91/100
# 1171/1171 - 0s - loss: 0.5363 - accuracy: 0.7182 - val_loss: 0.6365 - val_accuracy: 0.6507
# Epoch 92/100
# 1171/1171 - 0s - loss: 0.5349 - accuracy: 0.7259 - val_loss: 0.6338 - val_accuracy: 0.6712
# Epoch 93/100
# 1171/1171 - 0s - loss: 0.5342 - accuracy: 0.7276 - val_loss: 0.6368 - val_accuracy: 0.6712
# Epoch 94/100
# 1171/1171 - 0s - loss: 0.5329 - accuracy: 0.7259 - val_loss: 0.6372 - val_accuracy: 0.6712
# Epoch 95/100
# 1171/1171 - 0s - loss: 0.5333 - accuracy: 0.7301 - val_loss: 0.6375 - val_accuracy: 0.6575
# Epoch 96/100
# 1171/1171 - 0s - loss: 0.5312 - accuracy: 0.7225 - val_loss: 0.6408 - val_accuracy: 0.6712
# Epoch 97/100
# 1171/1171 - 0s - loss: 0.5313 - accuracy: 0.7301 - val_loss: 0.6357 - val_accuracy: 0.6644
# Epoch 98/100
# 1171/1171 - 0s - loss: 0.5308 - accuracy: 0.7276 - val_loss: 0.6402 - val_accuracy: 0.6644
# Epoch 99/100
# 1171/1171 - 0s - loss: 0.5323 - accuracy: 0.7242 - val_loss: 0.6341 - val_accuracy: 0.6575
# Epoch 100/100
# 1171/1171 - 0s - loss: 0.5299 - accuracy: 0.7301 - val_loss: 0.6422 - val_accuracy: 0.6575

# %% [markdown]
# We can see that our model is calculating predictions, but we have a problem: at some point, our val_loss starts increasing while our val_accuracy remains either static or continues to decrease. This means that our model is overfitting the data! It's learning too specifically for this particular problem. Therefore, we need to instruct the machine to stop learning right at the point at which the val_loss stops decreasing. We do this by specifying an early stopping method from Keras:

# %%
# Ok, so it's overfit
# need an early stopping mechanism

input_size = 10                
output_size = 2                 
hidden_layer_size = 50         

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size = 100

max_epochs = 100

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=1)

model.fit(train_inputs, train_targets, batch_size=batch_size, epochs=max_epochs, validation_data=(validation_inputs, validation_targets), verbose=2)
# Out:
# Train on 1171 samples, validate on 146 samples
# Epoch 1/7
# 1171/1171 - 0s - loss: 0.7367 - accuracy: 0.4338 - val_loss: 0.6910 - val_accuracy: 0.5479
# Epoch 2/7
# 1171/1171 - 0s - loss: 0.6781 - accuracy: 0.6063 - val_loss: 0.6627 - val_accuracy: 0.6438
# Epoch 3/7
# 1171/1171 - 0s - loss: 0.6431 - accuracy: 0.6815 - val_loss: 0.6433 - val_accuracy: 0.6644
# Epoch 4/7
# 1171/1171 - 0s - loss: 0.6196 - accuracy: 0.6917 - val_loss: 0.6377 - val_accuracy: 0.6781
# Epoch 5/7
# 1171/1171 - 0s - loss: 0.6073 - accuracy: 0.6951 - val_loss: 0.6331 - val_accuracy: 0.6781
# Epoch 6/7
# 1171/1171 - 0s - loss: 0.6011 - accuracy: 0.6934 - val_loss: 0.6356 - val_accuracy: 0.6781
# Epoch 7/7
# 1171/1171 - 0s - loss: 0.5970 - accuracy: 0.6994 - val_loss: 0.6274 - val_accuracy: 0.6712

# %% [markdown]
# This is likely to be a much more accurate model, at least as far as this data goes. We observe on our validation set that it seems that out of 10 nursing homes, our model is likely to accurately predict whether 7 of them will be cited for abuse. Not bad.

# %% [markdown]
# ### Testing the model
#
# If our model is valide, we ought to observe a similar result on our test data, which is data that the model has never seen. Let's see.

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 147/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100))
# Out:
# Test loss: 0.62. Test accuracy: 65.99%

# %% [markdown]
# Our model measures at just about 66% on the test data versus 67% on our validation data. We can expect this model to perform similarly on any data with the same features to predict the same outcome.

# %% [markdown]
# ## Limitations and Conclusion
#
# Obviously, we've only tested for 10 features here, and there were more than 30 valid features in the original data. We'd have to go through all of them to get a robust idea of all of the information that comes to bear on predicting whether a nursing home will be cited for abuse. Regardless, in this specific context, we can make this prediction using this model at 16 - 17% more accurately than a coin flip. That is statistically significant, not miraculous, but still important. More research will need to be done to determine how this information could be used to improve outcomes for patients and staff in a nursing home setting.

# %% [markdown]
# ## References
#
# Blankart, C. R., Foster, A. D., & Mor, V. (2019). The effect of political control on financial performance, structure, and outcomes of US nursing homes. Health Services Research, 1. edsbig. https://doi.org/10.1111/1475-6773.13061
#
# Dicken, J. E. (2019). NURSING HOMES: Improved Oversight Needed to Better Protect Residents from Abuse. GAO Reports, 1. pwh.
#
# Dummit, L. A. (2002). Nursing Homes: Quality of Care More Related to Staffing than Spending: GAO-02-431R. GAO Reports, 1.
#
# Grabowski, D. C., Stevenson, D. G., Caudry, D. J., O’Malley, A. J., Green, L. H., Doherty, J. A., & Frank, R. G. (2017). The impact of nursing home pay-for-performance on quality and medicare spending: Results from the nursing home value-based purchasing demonstration. Health Services Research, 4. edsbig. https://doi.org/10.1111/1475-6773.12538
#
# Harrington, C., Schnelle, J. F., McGregor, M., & Simmons, S. F. (2016). The Need for Higher Minimum Staffing Standards in U.S. Nursing Homes. Health Services Insights, 9, 13. edb.
#
# Jane Banaszak-Holl, Whitney B. Berta, Dilys M. Bowman, Joel A. C. Baum, & Will Mitchell. (2002). The Rise of Human Service Chains: Antecedents to Acquisitions and Their Effects on the Quality of Care in US Nursing Homes. Managerial and Decision Economics, 23(4/5), 261. edsjsr.
#
# Konetzka, R. T., Norton, E. C., & Stearns, S. C. (2006). Medicare Payment Changes and Nursing Home Quality: Effects on Long-Stay Residents. International Journal of Health Care Finance and Economics, 6(3), 173. edsjsr. https://doi.org/10.1007/s10754-006-9000-9
#
# Park, Y. J., & Martin, E. G. (2018). Geographic Disparities in Access to Nursing Home Services: Assessing Fiscal Stress and Quality of Care. Health Services Research, 4. edsbig. https://doi.org/10.1111/1475-6773.12801
#
# Trinkoff, A. M., Johantgen, M., Muntaner, C., & Le, R. (2005). Staffing and Worker Injury in Nursing Homes. American Journal of Public Health, 95(7), 1220–1225. pbh.
